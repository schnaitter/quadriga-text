# %% [markdown]
# # Analysis

# %% [markdown]
# Now we'll take the CONLL data and do some analysis. Like
# * plot the frequencies of some lemma
# * look at some lemmas contexts
# * analyze some lemmas collocations

# %% [markdown]
# ## 0. Imports and data upload

# %%
import pandas as pd

# %%
import re

# %%
import os

# %%
conllfiles = (r"../data/conll")

# %%
corpus_annotations = {}
for filename in os.listdir(conllfiles):
    if '.conll' in filename:
        path = os.path.join(conllfiles, filename)  
        data = pd.read_csv(path) 
        corpus_annotations[filename] = data

# %% [markdown]
# ## 1. Search lemma and plot frequency

# %%
class WordSearchEngine:
    
    def __init__(self, corpus_annotated):
        self.prepare_index_dataframe_for_search(corpus_annotated)
    
    def prepare_index_dataframe_for_search(self, corpus_annotated):
        for filename, annotated_text in corpus_annotated.items():
            year, month, day = self.get_date_fname(filename)
            annotated_text['month'] = month
        self.full_df = pd.concat(corpus_annotated.values())
        print(f'Searching in a corpus of {self.full_df.shape[0]} word occurences')
        
    def get_date_fname(self, filename):  ## REDO WITH METADATA
        date_pattern = re.search(r'(19\d\d)(\d\d)(\d\d)-0-0-0-0', filename)
        year = date_pattern.group(1)
        month = f'{year}-{date_pattern.group(2)}'
        day =  f'{month}-{date_pattern.group(3)}'
        return year, month, day    
        
    def search_and_plot(self):
        search_term = input('Insert a word to search: ')
        if len(search_term) == 0:
            search_term = 'Grippe'
        result = self.full_df.query(f'Lemma=="{search_term}"')
        result.groupby('month').count().Lemma.plot(title=f'frequency of {search_term}');

# %%
engine = WordSearchEngine(corpus_annotations)
# Out:
# Searching in a corpus of 3008370 word occurences

# %%
engine.search_and_plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/h_schnaitter/code/quadriga-text/word_search/FS_1_MVP_Analysis_Prototype_101.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/Users/h_schnaitter/code/quadriga-text/word_search/FS_1_MVP_Analysis_Prototype_101.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> engine.search_and_plot()
#
# /Users/h_schnaitter/code/quadriga-text/word_search/FS_1_MVP_Analysis_Prototype_101.ipynb Cell 12 line 2
#      <a href='vscode-notebook-cell:/Users/h_schnaitter/code/quadriga-text/word_search/FS_1_MVP_Analysis_Prototype_101.ipynb#X14sZmlsZQ%3D%3D?line=22'>23</a>     search_term = 'Grippe'
#      <a href='vscode-notebook-cell:/Users/h_schnaitter/code/quadriga-text/word_search/FS_1_MVP_Analysis_Prototype_101.ipynb#X14sZmlsZQ%3D%3D?line=23'>24</a> result = self.full_df.query(f'Lemma=="{search_term}"')
# ---> <a href='vscode-notebook-cell:/Users/h_schnaitter/code/quadriga-text/word_search/FS_1_MVP_Analysis_Prototype_101.ipynb#X14sZmlsZQ%3D%3D?line=24'>25</a> result.groupby('month').count().Lemma.plot(title=f'frequency of {search_term}')
#
# File ~/code/quadriga-text/venv/lib/python3.11/site-packages/pandas/plotting/_core.py:947, in PlotAccessor.__call__(self, *args, **kwargs)
#     946 def __call__(self, *args, **kwargs):
# --> 947     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     949     x, y, kind, kwargs = self._get_call_args(
#     950         plot_backend.__name__, self._parent, args, kwargs
#     951     )
#     953     kind = self._kind_aliases.get(kind, kind)
#
# File ~/code/quadriga-text/venv/lib/python3.11/site-packages/pandas/plotting/_core.py:1944, in _get_plot_backend(backend)
#    1941 if backend_str in _backends:
#    1942     return _backends[backend_str]
# -> 1944 module = _load_backend(backend_str)
#    1945 _backends[backend_str] = module
#    1946 return module
#
# File ~/code/quadriga-text/venv/lib/python3.11/site-packages/pandas/plotting/_core.py:1874, in _load_backend(backend)
#    1872         module = importlib.import_module("pandas.plotting._matplotlib")
#    1873     except ImportError:
# -> 1874         raise ImportError(
#    1875             "matplotlib is required for plotting when the "
#    1876             'default backend "matplotlib" is selected.'
#    1877         ) from None
#    1878     return module
#    1880 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %% [markdown]
# ## 2. Exploring the contexts
#
# Let us look at the contexts in which the words appear
#
#
# ### 2.1 KWIC

# %%
class ContextViewer:
    
    def __init__(self, corpus_annotated):
        self.full_df = self.prepare_index_dataframe_for_search(corpus_annotated)
        self.full_df = self.full_df.reset_index()
        #print(type(self.full_df))
        
    def prepare_index_dataframe_for_search(self, corpus_annotated):
        for filename, annotated_text in corpus_annotated.items():
            year, month, day = self.get_date_fname(filename)
            annotated_text['month'] = month
        return pd.concat(corpus_annotated.values())
        #print(f'Searching in a corpus of {self.full_df.shape[0]} word occurences')
        
    def get_date_fname(self, filename): ## REDO WITH METADATA
        date_pattern = re.search(r'(19\d\d)(\d\d)(\d\d)-0-0-0-0', filename)
        year = date_pattern.group(1)
        month = f'{year}-{date_pattern.group(2)}'
        day =  f'{month}-{date_pattern.group(3)}'
        return year, month, day    
        
    def get_context(self):
        search_lemma = input('Insert a word to search: ')
        if len(search_lemma) == 0:
            search_lemma = 'Grippe'
        indices = self.full_df.query(f'Lemma=="{search_lemma}"').index
        #print(indices)
        left_contexts = []
        this_words = []
        right_contexts = []
        months = []
        for indice in indices:
            left = self.full_df.iloc[indice-10:indice-1, ]["Token"]
            leftс = left[~left.str.contains('\n')]
            right = self.full_df.iloc[indice+1:indice+10, ]["Token"]
            rightс = right[~right.str.contains('\n')]
            left_contexts.append(' '.join(leftс))
            right_contexts.append(' '.join(rightс))
            this_words.append(self.full_df.iloc[indice, ]["Token"])
            months.append(self.full_df.iloc[indice, ]["month"])
        newdf = pd.DataFrame()
        newdf['left_context'] = left_contexts
        newdf['word'] = this_words
        newdf['right_context'] = right_contexts
        newdf['month'] = months
        return newdf #.sort_values(by='month')

# %%
kwic = ContextViewer(corpus_annotations)

# %%
kwic.get_context()
# Out:
#                                          left_context    word  \
# 0                        , 15. Oktober 1918. En LI IR  Grippe
# 1                    : Poſen , 14. Oltober . desfälle  Grippe
# 2               einzelne alten werden können . t ſich  Grippe
# 3           Meldung , Marſchall Io ffr e ſchwer krank  Grippe
# 4             wurde abgeſagt . Es beſtätigt fie , daß  Grippe
# 5                 || - Zahn- Praxis Klömpen Beize | a  Grippe
# 6         Feldlazarett | im Felde infolge Anſte > ung  Grippe
# 7      3. verſchied in einem Feld- 8 lazarett infolge  Grippe
# 8                von dem am 19. Oltober d. I. infolge  Grippe
# 9      Elfe , geb. Freudenthal . Infolge Erkrankung «  Grippe
# 10         entichlief heute nacht 3 Uhr an den Folgen  Grippe
# 11  Übertrieben . Die Krankheit wird als harmloſe ...  Grippe
# 12         Triebwagen- fahrt erjeßt . ; Die ſpaniſche  Grippe
# 13     in der lezten Woche 287 Todesfälle infolge der  Grippe
# 14                       ih mit dem Fluch „ Hol * Die  Grippe
# 15  dem deutſchen Vaterlande vine neue glüFliche Z...  Grippe
# 16  Woche “ durchſchnittlich .zuſqmmar täglich etw...  Grippe
# 17                        : und . " die | auch .die “  Grippe
# 18                    . Die Jufluenza im Reiche . Die  Grippe
# 19                = Auch in Frankfurt am Main iſt die  Grippe
# 20      das iſt Wandſchrunk verborgene Geld entde > t  Grippe
# 21                        in Streu l 241 die Zahl der  Grippe
# 22  ETEEENS leinexen weſtlichen Vororten und einde...  Grippe
# 23  der gleiſßen Zeit 1916. gekloten fehlten , da fie  Grippe
# 24        nach iurzom Krankentager is 3 an den Folgen  Grippe
# 25                            " 06 1918 15. Dktobey ?  Grippe
# 26  Deutſchland und der Schweiz . Uber dis Ausdehnung  Grippe
# 27            werden ſollen , = - In Ltegutz forderte  Grippe
# 28    im Laufe der pten Woche find dort 60 Todesfälle  Grippe
# 29  Oktober , | Nach Meldungen Schweizer Blätter o...  Grippe
# 30  Freiſprechung erkannt , Die ſpaniſche Krankhei...  Grippe
# 31                * Dienstag ( Morgen ) Die Fortdauer  Grippe
# 32  verbreitet folgende Auslaſſung der Grippe-Erkr...  Grippe
# 33  endigen , und ruhrartige Erkrankungen ſind im ...  Grippe
# 34         , daß ſte von den Kranken angehuſtet Fälle  Grippe
# 35       Sharlach 1 , Die der Todesfälle en Influenza  Grippe
# 36    Bruſt » und Rippenfellentzündung 1. 4 ' Infolge  Grippe
# 37             auc < ß in vielen Fällen gar nicht auf  Grippe
# 38  Verordnungen beſchäftigt , on den Angeklagten ...  Grippe
# 39              woil dann die Hen Uhr deim Nachlaſſen  Grippe
# 40            Vei Ortskranken « geſtern nur noch 1091  Grippe
# 41   , während die Geſundmeldungen 2000 überſchritt .  Grippe
# 42          nur noch 39 ge- Die Fahl der Erkrankungen  Grippe
# 43                            man ſie im voi M ; noſe  Grippe
# 44                 fic ) ein Abſlauen der . Die Fälle  Grippe
# 45  Einioe Todesfälle an Lungenentzündung im Zuſam...  Grippe
# 46           krankungen für Baden uad die Dagegen iſt  Grippe
# 47  vertreten und ei alten Parteien großer perjänl...  Grippe
# 48     den .Groß-Virliner Vororten S < ö neberg durch  Grippe
# 49     lolſen worden , als ein Drittel der Schüler an  Grippe
# 50                , us , Kolonial : ntage . Zeitgemäß  Grippe
# 51  Ut im blühenden Mannesalter nach kurzem Kranke...  Grippe
# 52                   . Fritz Behrens , Wieder hat die  Grippe
#
#                                         right_context    month
# 0    wütel weiter Zunahme der ſcheren Fälle in Berlin  1918-10
# 1              find in der vergan- „ auf 58 geſtiegen  1918-10
# 2                       aus . te fi die Grippewelle N  1918-10
# 3       darniederliegt . Sein Beſuch in England wurde  1918-10
# 4   , und gefährliche Epidemien im franzöſiſchen S...  1918-10
# 5                 DIRE Tr beite wi ; ichel im Gegſcht  1918-12
# 6     in „ treuen Pfichterſülung fürs | Vaterland der  1918-09
# 7         im 32 , Lebensjahre unſer Wi Prokurfft Sert  1918-10
# 8   erfolgten Hin- ſcheidens unſeres Prokuriſten ,...  1918-10
# 9   mit Lungenentzündung Jam nat kurzem , aber ſch...  1918-10
# 10  meine unvergeß » Tiche , herzensgute Geywieger...  1918-10
# 11                 be zei ichnet , die von den Erkran  1918-06
# 12                in London . In . London ſind in der  1918-07
# 13      zu verzeihnen geweſen , Die Ziffern- der drei  1918-07
# 14           ! “ das Billet zur beſſeren Hälfte durc-  1918-08
# 15  wieder in Spanien , „ zwr Drah4ämeldung-der --...  1918-09
# 16          “ Erkrankungen zu verzeichnen . Im Ftied-  1918-07
# 17  . oder . ufroiniſche Dowogung -gegen- die Dolſ...  1918-07
# 18                         iſt je ? auch in den Da n-  1918-07
# 19  aufgetreten , Sozialdemolraliſche Friedensbedi...  1918-07
# 20        . |S EE EEE | ile Scwnrgerihtsfäle | NEIGEN  1918-10
# 21  erkrankten | früheren Erfahrungen , er im Verlauf  1918-10
# 22                       nac ng eil über 36 v- H. der  1918-10
# 23      er- | Ml ekoriſchen bewieſen . Dem , Görliter  1918-10
# 24                  im Alten Lager bei Jüterbog | “ "  1918-11
# 25  und ihre Folgen , Auzsdreitung in Deutſchland und  1918-10
# 26          laufen no < F fortwährend Meldungen ein ,  1918-10
# 27        weiters Opfer ; Der größte Teil der Schulen  1918-10
# 28               ü mE geweſen , Zn vielen Etübten die  1918-10
# 29          in Her ganzen Schwetz - in ' bedenklicher  1918-10
# 30  iſt jeßt . auch in den Danziger Garniſonlazare...  1918-07
# 31        . DB . T. B. verbreitet folgende Auslaſſung  1918-10
# 32           , welche zuerſt im Zuli dieſes Jahres in  1918-10
# 33  beobachtet worden . Beſonders zahlreich ſind d...  1918-10
# 34  vorkommen , ſich beim Verkehr mit geſunden-Per- +  1918-10
# 35                        2 ) , an nentzündung 8 , en  1918-10
# 36  haben die ſämtlihen Wilmersdoxrfer Bdulen , hö...  1918-10
# 37        zurüc « zuführen . An einzelnen Schulen des  1918-10
# 38  ertrankt und deshalb nicht zur Stells Zwei Ang...  1918-10
# 39              in Berlin . Vei Ortskranken « geſtern  1918-10
# 40                » gen gemeldet worden , während die  1918-10
# 41                 waren 15 , an Lungenent- Neue Er ?  1918-10
# 42           Kreiſen Wiens erregen Mit- rkeit der Fag  1918-10
# 43                            . gen , Der und dos Fir  1918-07
# 44  it Lungenentzündung , ow-Krankenhaus am Sornabend  1918-07
# 45                liegen zwar no < vor . Aus Wweidniß  1918-07
# 46  in weitem Umſange in der ſäweizeriſcen Armee a...  1918-07
# 47              an < in Holland , Die hollin- diſchen  1918-07
# 48  im Schulbetrieb berührt worden Charlottenburg ...  1918-11
# 49  erkrankt war . Indeſſen bleiben einſtweilen , wie  1918-11
# 50                 , Gerippe . er Rennen zu nenden PR  1918-11
# 51  dahingerafft . Rach langjähriger Auslandstätig...  1918-11
# 52     ein edles Menſchen- leben dahingerafft . Am 2.  1918-11

# %% [markdown]
# ### 2.2 Collocations
